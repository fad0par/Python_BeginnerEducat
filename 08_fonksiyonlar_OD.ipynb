# %% [markdown]
# #PIP Aracıyla Kütüphane Ekleme
#
# Pip aracı konsol üzerinden Python kütüphanesi eklemeyi sağlayan bir araçtır. Pip ile bir şey yüklemek kolaydır.
#
#
# ```
# pip install KUTUPHANE_ADI
# ```

# %%
pip install ascii_magic
# Out:
# Collecting ascii_magic
#   Downloading ascii_magic-2.3.0-py3-none-any.whl.metadata (13 kB)
# Collecting colorama (from ascii_magic)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from ascii_magic) (11.1.0)
# Downloading ascii_magic-2.3.0-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.2/733.2 kB 13.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, ascii_magic
# Successfully installed ascii_magic-2.3.0 colorama-0.4.6

# %%
!
import ascii_magic
#Kütüphanenin içindeki ufak bir sınıf şöyle dahil edilir;
from ascii_magic import * #Yıldız işareti içindekileri hepsini dahil eder.

#Bayrak resmini indirip Colab2tan dosya olarak yükledikten sonra şunu yazıyoruz:
bayrak_resmi = AsciiArt.from_image('bayrak.png')
#Resmi Terminale yükleme
bayrak_resmi.to_terminal()

# %%
# !pip install ascii_magic
import ascii_magic
#Kütüphanenin içindeki ufak bir sınıf şöyle dahil edilir;
from ascii_magic import * #Yıldız işareti içindekileri hepsini dahil eder.

#Atatürk resmini indirip Colab2tan dosya olarak yükledikten sonra şunu yazıyoruz:
atam_resmi = AsciiArt.from_image('atam.jpg')
#Resmi Terminale yükleme
atam_resmi.to_terminal()

# %% [markdown]
# #Fonksiyonlar - Metotlar
# Farklı programlama dillerinde metotlar olarak bilinen fonksiyonlar, nesne tabanlı programlamamım temelidir. "Nesne Tabanlı Programlama (NTP)" İngilizce "Object Oriend Programming (OOP)" olarak bilinir. Bu programlama (NTP) yazılımda tekrar eden veya sonradan kullanılabilen işlemleri ve değişkenleri saklamayı amaçlar. <br>
#
# **Örneğin;**<br>
# 1. Bir listeyi birden fazla kez kullanmak istiyorsunuz diyelim. NTP bunu bir kez yazıp, aşağıdaki kodlarda tekrar çağırabilmemizi sağlar.
# 2. Bir mat işlemi yapıyoruz diyelim. Bu işlemi bir fonksiyonun içine saklayıp, o fonksiyonu çağırarak satırlarca kod yazmamıza engel olur.
# 3. Bir programda yazdığımız işlemleri başka bir programa yükleyerek veya dosyalarına ekleyerek onu kullanabiliriz. Bu işlemi import ile yaparız.
# Tıpkı kütüphane ekler gibi kendi kütüphanelerimizi oluşturabiliriz.
#
# ##Bir Fonksiyon Nasıl Oluşturulur?
#
# Fonksiyon oluşturmak oldukça basittir. Bu arada fonksiyonun türleri vardır. Buna sonra geleceğiz.
#
#
#
# ```
# def fonksiyon_adi(fonksiyonda_calisacak_degiskenler):
#   Çalışacak Kodlar
# ```

# %%
#ödev1
# !pip install ascii_magic
import ascii_magic
#Kütüphanenin içindeki ufak bir sınıf şöyle dahil edilir;
from ascii_magic import AsciiArt #Importing AsciiArt class specifically

#Bayrak resmini indirip Colab2tan dosya olarak yükledikten sonra şunu yazıyoruz:
tbmm_resmi = AsciiArt.from_image('tbmm.jpg')
#Resmi Terminale yükleme
tbmm_resmi.to_terminal()

# %%
#ödev2
sepet = []
girilen_sayı = int(input("bir sayi giriniz:"))
while girilen_sayı != 0:
  sepet.append(girilen_sayı)
  girilen_sayı = int(input("bir sayı giriniz"))
  if girilen_sayı == 0:
    print(sepet)

# %%
def giris():
  print("merhaba programa hoşgeldiniz")
  print("Bu bir fonksiyondur")
print("Yukarıda fonksiyon tanımlandı")
giris()

# %%
def Ali_yas():
  print("Ali'nin yaşını bilmek istiyorsak şu işlemi yapalım:")
  hesaplama = 2025 - 2010
  print("Ali'nin yaşı:", hesaplama)

#Ekrana yazması için yaz!
Ali_yas()
# Out:
# Ali'nin yaşını bilmek istiyorsak şu işlemi yapalım:
# Ali'nin yaşı: 15

# %%
def toplama_islemi():
  s1 = int(input("bir sayı giriniz:"))
  s2 = int(input("bir sayı giriniz:"))
  toplam = s1 + s2
  print("toplamı:", toplam)

# %%
toplama_islemi()

# %%
#3 sayıyı çarpan fonksiyon yaz
def carpma_islemi():
  s1 = int(input("bir sayı giriniz:"))
  s2 = int(input("bir sayı giriniz:"))
  s3 = int(input("bir sayı giriniz:"))
  carpim = s1 * s2 * s3
  print("çarpım:", carpim)
carpma_islemi(   )

# %% [markdown]
# ##Fonksiyona Parametre Yazma
# Fonksiyonda çalışacak değişkenlere parametre denir. Bu parametreler fonksiyonun içinde çalışacak değerlerdir. Ana programda yazılımcı zorunlu olarak bunu doldurmalıdır. İster doğrudan bir değe yazar isterse elle bilgi girer.

# %%
#Parametre parantez içine yazılır.
def kullanici_paneli(kullanici_adi, parola):
  if kullanici_adi == "Gary" and parola == "12A34B":
    print("başarılı kullacı girişi!")
  else:
    print("başarısız giriş!")

k_adi = input("kullanıcı adınızı giriniz:")
sifre = input("şifrenizi giriniz:")
kullanici_paneli(k_adi, sifre)

# %%
def kullanici_paneli(kullanici_adi, parola):
  if kullanici_adi == "4" and parola == "H":
    print("Hoşgeldiniz!")
  else:
    print("Bu sınıfa ait değilsiniz!")

sınıf = input("sınıfınızı giriniz:")
sube = input("şubenizi giriniz:")
kullanici_paneli(sınıf, sube)
# Out:
# sınıfınızı giriniz:4
# şubenizi giriniz:H
# Hoşgeldiniz!

# %%
def kullanici_bilgileri_al_ve_yazdir():
    ad = input("Adınızı girin: ")
    soyad = input("Soyadınızı girin: ")
    yas = input("Yaşınızı girin: ")
    okul = input("Okuduğunuz okulun adını girin: ")

    print("\n--- Kullanıcı Bilgileri ---")
    print(f"Ad: {ad}")
    print(f"Soyad: {soyad}")
    print(f"Yaş: {yas}")
    print(f"Okul: {okul}")

kullanici_bilgileri_al_ve_yazdir()
# Out:
# Adınızı girin: kerem
# Soyadınızı girin: parpar
# Yaşınızı girin: 16
# Okuduğunuz okulun adını girin: coşkunöz
#
# --- Kullanıcı Bilgileri ---
# Ad: kerem
# Soyad: parpar
# Yaş: 16
# Okul: coşkunöz

# %% [markdown]
# #Not Ortalaması Hesaplama
#
# Mat dersinden bir sınıf sınav oluyor diyelim. Bu dersin not ort. hesaplamak istiyorsak 3 tane sınav notunu toplar 3'e böleriz. Benzer şekilde Türkçe dersinden ise 4 sınav olunuyor. Bu 4 sınavın not ort hesaplamak için 4 sınavın notunu toplar'e böleriz.
#
#
#
#
# ```
# SONUÇ: Kaç tane sınav oluyorsam sınav notlarını toplar, not sayısına bölerim.
# ```

# %%
#1.Yöntem
def not_ortalama(sayi):
  sayi = int(input("Notunuzu Giriniz(Çıkmak için -1 yaz):"))
  toplam = 0
  ort = 0
  girilen_not_sayisi = 0
  while sayi != 0:
    toplam += sayi
    girilen_not_sayisi += 1
    sayi = int(input("Notunuzu Giriniz(Çıkmak için -1 yaz):"))
    if(sayi == -1):
      break
  ortalama = toplam / girilen_not_sayisi
  print("ortalamanız:",float(ortalama))
  return ortalama
  not_ortalama(sayi)
  if  ortalama >= 85 and ortalama <= 100:
    print("Sınavı çok iyi geçtiniz")
  elif ortalama >= 70 and ortalama <= 84:
    print("Sınavı harika geçtiniz")
  elif ortalama >= 50 and ortalama <= 69:
    print("Sınavı ortalama ile geçtiniz")
  elif ortalama >= 30 and ortalama <= 49:
    print("Sınavı Kötü ile geçtiniz")
  elif ortalama >= 0 and ortalama <= 29:
    print("Sınavı geçemediniz")
  else:
    print("Lütfen bir not girin")

# %%
sayim = int(input("Lütfen sayı giriniz:"))
not_ortalama(sayim)
# Out:
# Lütfen sayı giriniz:100
# Notunuzu Giriniz(Çıkmak için -1 yaz):100
# Notunuzu Giriniz(Çıkmak için -1 yaz):95
# Notunuzu Giriniz(Çıkmak için -1 yaz):100
# Notunuzu Giriniz(Çıkmak için -1 yaz):-1
# ortalamanız: 98.33333333333333
# 98.33333333333333

# %%
#2.Yöntem
def not_for_hesaplama( sayi_adedi):
  toplama = 0
  ort = 0
  for a in range(0, sayi_adedi):
    sayi = int(input("Notunuzu giriniz:"))
    toplama += sayi
  ortalama = toplama / sayi_adedi
  print("ortalamanız:", float(ortalama))

# %%
sayim = int(input("Lütfen sayı giriniz:"))
not_for_hesaplama(sayim)
# Out:
# Lütfen sayı giriniz:2
# Notunuzu giriniz:99
# Notunuzu giriniz:100
# ortalamanız: 99.5

# %%
#ödev
sayi = input("Lütfen bir sayı giriniz: ")
toplam = 0
for rakam in sayi:
    toplam += int(rakam)
print("Rakamların toplamı:", toplam)
# Out:
# Bir sayı girin: 1905
# Rakamların toplamı: 15

# %%
#Hesap Makinesi
#KÜTÜPHANELER
import math as m #Matematik kütüphanesi

#İŞİME YARAYACAK DEĞİŞKENLER
sayilarim = [] #4 işlemin yapılacağı liste
islem_no = 0 #Ekranda işlem seçimim
dongu = True #Döngümün çalışacağı koşul

#İŞLEMLERİM YAZILIR
#Ekrana yazdırılacakları görmüş olalım.
def ekrana_yazdir():
  print("1- Toplama")
  print("2- Çıkarma")
  print("3- Çarpma")
  print("4- Bölme")
  print("5- Üslü Sayı")
  print("6- Kareköklü Sayı")
  print("7- Faktöriyel Hesaplama")
  print("8- EBOB")
  print("0- Çıkış")

#Matematiksel İşlemler
#1-Toplama
def toplama(sayilarim): #Sayilarim bir listedir (String)
  toplam = 0 #Sayıların toplanacağı değişken
  for a in sayilarim: #For döngüsü ile listedeki elemanları tek tek alıyorum.
    toplam += int(a) #Aldığım her bir sayıyı toplam değişkeninin içine atıyorum.
  return toplam #Son olarak toplam değişkenini ekrana yazdırıyorum.

#2-Çıkarma
def cikarma(sayilarim): #Sayilarim bir listedir (String)
  sonuc = 0
  for a in sayilarim:
    sonuc -= int(a)
  return sonuc

#3-Çarpma
def carpma(sayilarim): #Sayilarim bir listedir (String)
  sonuc = 1 #Çarpma 1'dir 0 değil
  for a in sayilarim:
    sonuc *= int(a)
  return sonuc

#4-Bölme
def bolme(sayilarim): #Sayilarim bir listedir (String)
  sonuc = 0
  for a in sayilarim:
    sonuc /= int(a)
  return sonuc

#5-Üslü Sayı -> Bir sayıyı kendisiyle kaç kere çarpacağımızı belirtiyoruz.
def uslusayi():
  birinci_sayi = int(input("Hangi sayıyı çarpacaksınız?"))
  ikinci_sayi = int(input("Kaç kere çarpacaksınız?"))
  sonuc = 1
  for a in range(1,(ikinci_sayi+1)):
    sonuc *= birinci_sayi
  print("İşlem Sonucunuz: ", sonuc)

#6-Köklü Sayı -> Bir sayının karekökünü alma
def karekok():
  sayi = int(input("Karekökü alınacak sayıyı giriniz:"))
  sonuc = m.sqrt(sayi)
  print("İşlem Sonucunuz: ",sonuc)

#7-Faktöriyel Hesaplama -> Bir sayının 1'den kendisine kadar olan sayıların çarpımıdır.
def faktoriyel():
  sayi = int(input("Faktöriyeli alınacak sayıyı giriniz: "))
  sonuc = m.factorial(sayi)
  print(sayi,"! sonucu: ", sonuc)

#8-EBOB -> En Büyük Ortak Bölen Hesaplama
def EBOB():
  sayi1 = int(input("Birinci sayıyı giriniz:"))
  sayi2 = int(input("İkinci sayıyı giriniz:"))
  sonuc = m.gcd(sayi1,sayi2)
  print("EBOB işleminin sonucu: ",sonuc)

#ANA PROGRAM
while dongu == True:
  ekrana_yazdir()
  islem_no = input("Lütfen yukarıdaki işlemi seçiniz:")
  if islem_no == "0":
    dongu=False
    break
  elif islem_no == "1":
    sayi= int(input("Toplanacak sayıları tek tek yazın(0 ile bitirin):"))
    while(sayi !=0):
      sayilarim.append(sayi)
      sayi= int(input("Toplanacak sayıları tek tek yazın(0 ile bitirin):"))
    sonuc = toplama(sayilarim)
    print("Toplama işleminizin sonucu:", sonuc)
  elif islem_no == "2":
    sayi= int(input("Çıkarılacak sayıları tek tek yazın(0 ile bitirin):"))
    while(sayi !=0):
      sayilarim.append(sayi)
      sayi= int(input("Çıkarılacak sayıları tek tek yazın(0 ile bitirin):"))
    sonuc = cikarma(sayilarim)
    print("Çıkarma işleminizin sonucu:", sonuc)
  elif islem_no == "3":
    sayi= int(input("Çarpılacak sayıları tek tek yazın(0 ile bitirin):"))
    while(sayi !=0):
      sayilarim.append(sayi)
      sayi= int(input("Çarpılacak sayıları tek tek yazın(0 ile bitirin):"))
    sonuc = carpma(sayilarim)
    print("Çarpma işleminizin sonucu:", sonuc)
  elif islem_no == "4":
    sayi= int(input("Bölünecek sayıları tek tek yazın(0 ile bitirin):"))
    while(sayi !=0):
      sayilarim.append(sayi)
      sayi= int(input("Bölünecek sayıları tek tek yazın(0 ile bitirin):"))
    sonuc = bolme(sayilarim)
    print("Bölme işleminizin sonucu:", sonuc)
  elif islem_no == "5":
    uslusayi()
  elif islem_no == "6":
    karekok()
  elif islem_no == "7":
    faktoriyel()
  elif islem_no == "8":
    EBOB()

# %%
def selamla():
  ad = str(input("adınızı giriniz:"))
  if ad:
    print("merhaba",str(ad))
  else:
    print("Merhaba Arkadaşlar!")


selamla()

# %%
import random
#1. 2 tane listeye ihtiyacımız var
kullanicinin_sayilari = []
rastgele_sayilar = []

#2. kullanıcı 1 ile 50 arasında toplam 6 tane rakam girecek
for a in range(0,6):  sayi = int(input("1-50 arasında sayı giriniz:"))
  kullanicinin_sayilari.append(sayi)

#3. bilgisayar rastgele 6 sayı üretecek
for b in range(0,6):
  rast_sayi = random.randint(1,50)
  rastgele_sayilar.append(rast_sayi)

#4. iki listedeki elemanları sırasıyla karşılaştıracağım.
for c in range(0,6):
  if kullanicinin_sayilari[c] == rastgele_sayilar[c]:
    print("bir eşleme bulundu")
    print(kullanicinin_sayilari[c],"=",rastgele_sayilar[c])

print(kullanicinin_sayilari,"\n",rastgele_sayilar)

# %% [markdown]
# #OS KÜTÜPHANESİYLE DOSYA İŞLEMLERİ YAPMA
#
# OS kütüphanesi "Operating System" yani "İşletim sistemi" anlamına gelmektedir. Dosya açma, oluşturma, klasör yollarını öğrenme, klasör oluşturma gibi işleim sisteminizde gezinmenizi sağlayan bir kütüphanedir.

# %%
import os

#NOT: Oluşturacağınız dosyanın uzantısını bilmeniz gerekir.
#Word dosyasının uzantısı .docx
#Not defterinin uzantısı  .txt
#Örnek bir resim dosyası .png olabilir.

dosya = open("ad_soyad.txt","w")
#os.open -> bbir dosya aç demek. bu dosya klasör veya herhangi bir dosya olabilir.
# w -> write yani dosyaya yaz demek
# r -> read sadece oku demek
# a -> all yani hem yaz hem oku

#Write ile  dosyaya istediğimizi yazabiliriz.
dosya.write("Kerem Parpar \n Haşmet Dayı Pizza Tester")
#Yazdıktan sonra açtığımız dosyayı kapatmalıyız.
dosya.close()

# %%
okuma = open("ad_soyad.txt","r")
print(okuma.read())
okuma.close()
# Out:
# Kerem Parpar
#  Haşmet Dayı Pizza Tester

# %%
muhasebe = open("defter.txt","w")
bilgin = input("Lütfen son aylık bilgilerinizi yazınız:")
muhasebe.write(bilgin)
muhasebe.close()

yazdir = open("defter.txt","r")
print(yazdir.read())
yazdir.close()

# %%
#Bulunduğumuz klasörün bize yolunu söyler.
dosya_yolu = os.getcwd()
print(dosya_yolu)
# Out:
# /content

# %%
#os kütüphanesinden verileri nasıl ayrıca çekeriz?
import os
hasmets_place = open("personel.txt","w")
personel_adi = []
personel_maas = []

while True: #Ben kırana kdr çalışmaya devam et.
  personel_bilgi = input("Lütfen çalışan adını giriniz:")
  personel_para = int(input("Lütfen maaş giriniz:"))
  personel_adi.append(personel_bilgi)
  personel_maas.append(personel_para)
  if personel_bilgi == "0" or personel_para == 0:
    #personel_adi.remove(personel_bilgi)
    #personel_maas.remove(personel_para)
    break

#Yazma işlem bitince not defterine bilgileri ekleyelim.
for bilgi in personel_bilgi:
  for maas in personel_maas:
    verilerim = str(bilgi)+"-"+str(maas)+"TL"
    hasmets_place.writelines(str(verilerim))
hasmets_place.close()
# Out:
# Lütfen çalışan adını giriniz:fçci
# Lütfen maaş giriniz:26
# Lütfen çalışan adını giriniz:d.fidx
# Lütfen maaş giriniz:0
