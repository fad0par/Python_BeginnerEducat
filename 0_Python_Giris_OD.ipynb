# %% [markdown]
# #Çalıştığım Sunucunun Bilgileri

# %%
# !nvidia-smi
# Out:
# Sat Dec 14 10:10:08 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# *italik metin* #Python ilk Kod
# Python'a giriş dersinde ilk olarak bilgisayara yazı yazdırıyoruz!

# %%
print("HELLO WORD!")
# Out:
# HELLO WORD!

# %%
print(2+8)
# Out:
# 10

# %%
print(str(2)+""+str(8))
# Out:
# 28

# %% [markdown]
# **String:** Metin değişkenleri anlamına gelir. "" (Çift Tırnak) işareti
# arasına yazılır. Sayıları metine dönüştürürken str(sayi) içine yazarız.
#
# **Integer:** Sayı değişkenleri anlamına gelir. Sadece sayının kendisi yazılır.
# Sayıya çevirmek için int(sayi) yazarız.

# %%
print(len("MATEMATİK"))
# Out:
# 9

# %% [markdown]
# **Not-1:** Sayıları metinlere çevirebilirim ancak metinleri sayıya çeviremem.
#
# **Not-2:** Metinlerin harf sayısını(uzunluğunu) öğrenebilirim.
#
# **len():** Parantez içine çift tırnakla bir yazı yazarsam bana harf sayısını verir.

# %%
print(23+9)
print(23-9)
print(23*9)
print(23/9)
# Out:
# 32
# 14
# 207
# 2.5555555555555554

# %%
print((23+9),(23-9),(23*9),(23/9))
print((23+9)+(23-9)+(23*9)+(23/9))
# Out:
# 32 14 207 2.5555555555555554
# 255.55555555555554

# %%
print("Merhaba ben","Haşmet Dayı","Yapay zekasıyım.")
print("Size radyoaktif"+"Bir ürün getirmekteyim"+"Size nasıl yardımcı olabilirim?")
# Out:
# Merhaba ben Haşmet Dayı Yapay zekasıyım.
# Size radyoaktifBir ürün getirmekteyimSize nasıl yardımcı olabilirim?

# %%
print("Haşmet Dayı'nın günün menüsü: \n"+"Kuru Fasulye ve Pilav \n"+"The Ayran")
# Out:
# Haşmet Dayı'nın günün menüsü:
# Kuru Fasulye ve Pilav
# The Ayran

# %% [markdown]
# ödev:

# %%
print("kerem","parpar","yas=16")
#ödev1
# Out:
# kerem parpar yas=16

# %%
print(1900+5)
print(1910-5)
print(385*5)
print(9525/5)
#ödev2
# Out:
# 1905
# 1905
# 1925
# 1905.0

# %%
print("Kerem \n","Ceyda \n","Hakan \n")
#ödev3
# Out:
# Kerem
#  Ceyda
#  Hakan

# %%
print(16-5)
#ödev4
# Out:
# 11

# %%
print("Haşmet Dayı'nın Salı gününün menüsü: \n"+"Mercimek çorba \n"+"İskender \n"+"Kola \n"+"Trileçe")
#ödev5
# Out:
# Haşmet Dayı'nın Salı gününün menüsü:
# Mercimek çorba
# İskender
# Kola
# Trileçe
