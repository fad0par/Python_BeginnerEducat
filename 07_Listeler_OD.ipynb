# %% [markdown]
# #Liste
# Bazen bir konuda veya aynı türden birden fazla bilgiyi saklamak için listeler kullanılır. Değişkenler sadece bir türden ve sadece bir veri saklarken listeler birden fazla veriyi farklı türden saklayabilir. Önce ismi belirlenir sonra eşittir konulur ve köşeli parantez içerisine değerler yazılır.

# %%
sehirler =["adana","bursa","istanbul"]

# %% [markdown]
# Listelerin içerisine aynı türden olabileceği gibi farklı türden (sayı,metin, True/false) bilgileri de saklayabiliriz! Ayrıca listeleri ekranda görmemiz için listeleri ekrana yazdırmamız gerekir!

# %%
rastgele_liste = ["elma",12,"bilinmez",42,"çorba",True,421.1]
print(rastgele_liste)
# Out:
# ['elma', 12, 'bilinmez', 42, 'çorba', True, 421.1]

# %%
haftanin_gunleri = ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
print(haftanin_gunleri[2])
print(haftanin_gunleri[0])
print(haftanin_gunleri[5])
# Out:
# ['pazartesi', 'salı', 'çarşamba', 'perşembe', 'cuma', 'cumartesi', 'pazar']

# %% [markdown]
# **NOT** Listelerde bir elemanı içinden çağırmak istiyorsak listenin adını yazıp yanına köşeli parantez [] açıp içerisine rakam yazıyoruz. Bu rakam 0'dan başlar ve listenin eleman sayısının 1 eksiğine kdr gider. Mesela haftanın 7'yse listedeki elemanları 0 ve 6 arasında yazdırabilirim.
#
# Böylece ilk eleman 0'dır. Bu köşeli parantez içindeki değerlere **listenin indisi** denir.

# %%
import random
maker_listesi = ["kerem","ali kerem","demir","haşmet dayı","kay","ebubekir"]
rastgele_indis = random.randint(0,len(maker_listesi)-1)
#Önemli NOT: len listenin uzunluğunu verir. Listeler 0'dan başladığı için bir tane sayı fazladan yer alır. 0 yüzden -1 ile liste sayısını düşürürüz.
print(maker_listesi[rastgele_indis])
# Out:
# ebubekir

# %%
import random
haftanin_gunleri =  ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
rastgele_sayı = [1,2,3,4,5,6,7]
tatlı = ["trileçe","kemal paşa","sütlaç","puding","baklava","pasta","tel kadayıf"]
rastgele_sayı = random.randint(0,len(haftanin_gunleri)-1)
print(haftanin_gunleri[rastgele_sayı],"gününün tatlısı",tatlı[rastgele_sayı])
# Out:
# pazar gününün tatlısı tel kadayıf

# %%
#ödev
türkiye_illeri = ["adana","adıyaman","afyon","ağrı","amasya","ankara","antalya","artvin","aydın","balıkesir","bilecik","bingöl","bitlis","bolu","burdur","bursa","çanakkale","çankırı","çorum","denizli","diyarbakır","edirne","elazığ","erzincan","erzurum","eskişehir","gaziantep","giresun","gümüşhane","hakkari","hatay","ısparta","mersin","istanbul","izmir","kars","kastamonu","kayseri","kırklareli","kırşehir","kocaeli","konya","kütahya","malatya","manisa","kahramanmaraş","mardin","muğla","muş","nevşehir","niğde","ordu","rize","sakarya","samsun","siirt","sinop","sivas","tekirdağ","tokat","trabzon","tunceli","şanlıurfa","uşak","van","yozgat","zonguldak","aksaray","bayburt","karaman","kırkkale","batman","şırnak","bartın","ardahan","ığdır","yalova","karabük","kilis","osmaniye","düzce"]
print(türkiye_illeri[15])
# Out:
# bursa

# %% [markdown]
# #Listelere Input ile eleman ekleme ve çıkarma
# Input kullanarak listelere eleman ekleyip çıkarabiliriz. Bazı programlama dillerinde add (ekleme) veya append (listeyi içine ekleme) anlamına gelen bir fonksiyon ile ekleme yapılabilir. <br>
#
# Çıkarma işlemlerinde delete (silme) veya remove (listeden çıkarma) anlamında bu fonksiyonlar kullanılabilir. İkisinden örnek vermek gerekirse liste.append(sayi) veya liste.remove(3) gibi farklı şekillerde kullanılabilir

# %%
tatlilar = ["trileçe","kemal paşa","sütlaç","puding","baklava","pasta","kadayıf"]
tatli = input("Lütfen tatlı giriniz:")
tatlilar.append(tatli)
print(tatlilar)
#Listeden ekleneni silebilirim.
tatlilar.remove(tatli)
print("silme işlemi")
print(tatlilar)
silinecek_tatli = input("Lütfen silinecek tatlıyı giriniz:")
tatlilar.remove(silinecek_tatli)
print("Ekstra silmeden sonra:", tatlilar)
# Out:
# Lütfen tatlı giriniz:puding
# ['trileçe', 'kemal paşa', 'sütlaç', 'puding', 'baklava', 'pasta', 'kadayıf', 'puding']
# silme işlemi
# ['trileçe', 'kemal paşa', 'sütlaç', 'baklava', 'pasta', 'kadayıf', 'puding']
# Lütfen silinecek tatlıyı giriniz:kadayıf
# Ekstra silmeden sonra: ['trileçe', 'kemal paşa', 'sütlaç', 'baklava', 'pasta', 'puding']

# %% [markdown]
# #Listelerde Farklı İşlemler
# Listeleri temizleme, eleman seçip aynı anda çıkarma, listeyi tersten yazdırma, liste eleman sayısı veya indis bilgisi alma gibi işlemler yapabiliriz.

# %%
#Clear komutu -> Her şeyi sildi.
haftanin_gunleri = ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
haftanin_gunleri.clear()
print(haftanin_gunleri)

# %%
#Count komutu -> Yazılan elemanı sayar.
haftanin_gunleri = ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
gun = haftanin_gunleri.count("salı")
print(gun)

# %%
#Index komutu -> Yazılan elemanın kaçıncı index olduğunu yazar.
haftanin_gunleri = ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
print(haftanin_gunleri.index("çarşamba"))

# %%
#pop komutu -> Listenin içinden bahsedilen index'li elemanları alır yazar ve listeden çıkarır.
haftanin_gunleri = ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
gun = haftanin_gunleri.pop(3)
print(gun)
print(haftanin_gunleri)
# Out:
# perşembe
# ['pazartesi', 'salı', 'çarşamba', 'cuma', 'cumartesi', 'pazar']

# %%
#reverse komutu -> Listeyi ters çevirir.
haftanin_gunleri = ["pazartesi","salı","çarşamba","perşembe","cuma","cumartesi","pazar"]
haftanin_gunleri.reverse()
print(haftanin_gunleri)
# Out:
# ['pazar', 'cumartesi', 'cuma', 'perşembe', 'çarşamba', 'salı', 'pazartesi']

# %% [markdown]
# #Listelerdeki Arama yapma ve döngü kullanımı
# Listeler içerisinde belirli koşullar sağlandığında yazdırılacak veya işe yaracak bilgileri alabilmek için listelerde arama yapılmalıdır. Listelerde arama yapmak için döngüler kullanılabilir.

# %%
# 0-250 arasına 3'er 3'er sayıları yazdırma
ucerli_liste = []
onbesin_kati = []
for a in range(0,250,3):
  ucerli_liste.append(a)
print(ucerli_liste)
print("Toplam eleman sayısı",len(ucerli_liste))
#Bu listenin içinden 5'e bölünen sayıları ekrana yazdırma
for eleman in range(0,len(ucerli_liste)-1):
  if ucerli_liste[eleman] % 5 == 0:
    onbesin_kati.append(ucerli_liste[eleman])
print(onbesin_kati)
print("Toplam eleman sayısı",len(onbesin_kati))
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249]
# Toplam eleman sayısı 84
# [0, 15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 180, 195, 210, 225, 240]
# Toplam eleman sayısı 17

# %%
#ödev
import random
çorba = ["mercimek","yoğurt","domates","tarhana","ezogelin","brokoli","patates","şehriye","tavuk suyu","kelle paça"]
ana_yemek = ["iskender","tavuk","tas kebabı","sulu köfte","köfte","ıspanak","mantı","makarna","kuru fasulye","nohut"]
içecek = ["ayran","kola","pepsi","ice tea","su","çay","şalgam","komposto","gazoz","limonata"]
tatlı = ["puding","dondurmalı künefe","trileçe","kemal paşa","kazandibi","sütlaç","süt helvası","pasta","kabak"]
çorba_indis = random.randint(0,len(çorba)-1)
ana_yemek_indis = random.randint(0,len(ana_yemek)-1)
içecek_indis = random.randint(0,len(içecek)-1)
tatlı_indis = random.randint(0,len(tatlı)-1)
print("Bugün menüsü")
print("Çorba:",çorba[çorba_indis])
print("Ana yemek:",ana_yemek[ana_yemek_indis])
print("İçecek:",içecek[içecek_indis])
print("Tatlı:",tatlı[tatlı_indis])
# Out:
# Bugün menüsü
# Çorba: ezogelin
# Ana yemek: mantı
# İçecek: komposto
# Tatlı: süt helvası
